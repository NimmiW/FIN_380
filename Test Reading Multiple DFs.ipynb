# %% [markdown]
# Test File

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
# %matplotlib inline

# %%
initfile = 'opra_20170705_bar01_AAPL.csv.gz'

# %%
# Headers
labels = "TradingDate,UnderlyingTicker,UnderlyingType,OptionRoot,ExpirationDate,StrikePrice,OptionRight,StartBarTime,EndBarTime,OpenBidPrice,OpenAskPrice,HighBidPrice,HighAskPrice,LowBidPrice,LowAskPrice,CloseBidPrice,CloseBidSize,CloseAskPrice,CloseAskSize,NBBOBidExchange,NBBOAskExchange,NumberOfQuotes,MinQuoteSpread,MaxQuoteSpread,OpenTradePrice,HighTradePrice,LowTradePrice,CloseTradePrice,SumTradeValue,SumTradeSize,NumberOfTrades,CloseBidPriceExA,CloseBidSizeExA,CloseAskPriceExA,CloseAskSizeExA,CloseBidPriceExB,CloseBidSizeExB,CloseAskPriceExB,CloseAskSizeExB,CloseBidPriceExC,CloseBidSizeExC,CloseAskPriceExC,CloseAskSizeExC,CloseBidPriceExE,CloseBidSizeExE,CloseAskPriceExE,CloseAskSizeExE,CloseBidPriceExH,CloseBidSizeExH,CloseAskPriceExH,CloseAskSizeExH,CloseBidPriceExI,CloseBidSizeExI,CloseAskPriceExI,CloseAskSizeExI,CloseBidPriceExJ,CloseBidSizeExJ,CloseAskPriceExJ,CloseAskSizeExJ,CloseBidPriceExM,CloseBidSizeExM,CloseAskPriceExM,CloseAskSizeExM,CloseBidPriceExN,CloseBidSizeExN,CloseAskPriceExN,CloseAskSizeExN,CloseBidPriceExQ,CloseBidSizeExQ,CloseAskPriceExQ,CloseAskSizeExQ,CloseBidPriceExT,CloseBidSizeExT,CloseAskPriceExT,CloseAskSizeExT,CloseBidPriceExW,CloseBidSizeExW,CloseAskPriceExW,CloseAskSizeExW,CloseBidPriceExX,CloseBidSizeExX,CloseAskPriceExX,CloseAskSizeExX,CloseBidPriceExZ,CloseBidSizeExZ,CloseAskPriceExZ,CloseAskSizeExZ"

labels = labels.split(',')

# %%
# Makeshift way to change these column headers:
nums = list(range(0,87))

# Create a new dict
newcols = dict(zip(nums,labels))

# %%
expdate = '12/15/2017'

# %%
strprice = 170
optiontype = 'C'

# %%
df = pd.read_csv(initfile,header=None)

# %%
df = df.rename(columns=newcols)

# %% [markdown]
# df.drop([
#  'OptionRoot',
#  'NBBOBidExchange',
#  'NBBOAskExchange',
#  'CloseBidPriceExA',
#  'CloseBidSizeExA',
#  'CloseAskPriceExA',
#  'CloseAskSizeExA',
#  'CloseBidPriceExB',
#  'CloseBidSizeExB',
#  'CloseAskPriceExB',
#  'CloseAskSizeExB',
#  'CloseBidPriceExC',
#  'CloseBidSizeExC',
#  'CloseAskPriceExC',
#  'CloseAskSizeExC',
#  'CloseBidPriceExE',
#  'CloseBidSizeExE',
#  'CloseAskPriceExE',
#  'CloseAskSizeExE',
#  'CloseBidPriceExH',
#  'CloseBidSizeExH',
#  'CloseAskPriceExH',
#  'CloseAskSizeExH',
#  'CloseBidPriceExI',
#  'CloseBidSizeExI',
#  'CloseAskPriceExI',
#  'CloseAskSizeExI',
#  'CloseBidPriceExJ',
#  'CloseBidSizeExJ',
#  'CloseAskPriceExJ',
#  'CloseAskSizeExJ',
#  'CloseBidPriceExM',
#  'CloseBidSizeExM',
#  'CloseAskPriceExM',
#  'CloseAskSizeExM',
#  'CloseBidPriceExN',
#  'CloseBidSizeExN',
#  'CloseAskPriceExN',
#  'CloseAskSizeExN',
#  'CloseBidPriceExQ',
#  'CloseBidSizeExQ',
#  'CloseAskPriceExQ',
#  'CloseAskSizeExQ',
#  'CloseBidPriceExT',
#  'CloseBidSizeExT',
#  'CloseAskPriceExT',
#  'CloseAskSizeExT',
#  'CloseBidPriceExW',
#  'CloseBidSizeExW',
#  'CloseAskPriceExW',
#  'CloseAskSizeExW',
#  'CloseBidPriceExX',
#  'CloseBidSizeExX',
#  'CloseAskPriceExX',
#  'CloseAskSizeExX',
#  'CloseBidPriceExZ',
#  'CloseBidSizeExZ',
#  'CloseAskPriceExZ',
#  'CloseAskSizeExZ',
#  'UnderlyingType',
#  'NumberOfQuotes',
#  'SumTradeValue',
#  'SumTradeSize',
#  'OpenTradePrice',
#  'HighTradePrice',
#  'LowTradePrice',
#  'CloseTradePrice',
#  87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105],axis=1,inplace=True)

# %%
df = df.filter(['TradingDate',
                'UnderlyingTicker',
                'ExpirationDate',
                'StrikePrice',
                'OptionRight',
                'StartBarTime',
                'EndBarTime',
                'OpenBidPrice',
                'OpenAskPrice',
                'HighBidPrice',
                'HighAskPrice',
                'LowBidPrice',
                'LowAskPrice',
                'CloseBidPrice',
                'CloseBidSize',
                'CloseAskPrice',
                'CloseAskSize','MinQuoteSpread',
                'MaxQuoteSpread','NumberOfTrades'], axis=1)

# %%
df.columns
# Out:
# Index(['TradingDate', 'UnderlyingTicker', 'ExpirationDate', 'StrikePrice',
#        'OptionRight', 'StartBarTime', 'EndBarTime', 'OpenBidPrice',
#        'OpenAskPrice', 'HighBidPrice', 'HighAskPrice', 'LowBidPrice',
#        'LowAskPrice', 'CloseBidPrice', 'CloseBidSize', 'CloseAskPrice',
#        'CloseAskSize', 'MinQuoteSpread', 'MaxQuoteSpread', 'NumberOfTrades'],
#       dtype='object')

# %%
df = df[(df['ExpirationDate']==expdate)]

# %%
df = df[(df['StrikePrice']==strprice) & (df['OptionRight']==optiontype)]
# df.set_index('TradingDate',inplace=True)

# %%
df.head()
# Out:
#      TradingDate UnderlyingTicker ExpirationDate  StrikePrice OptionRight  \
# 1520  07/05/2017             AAPL     12/15/2017        170.0           C
# 3082  07/05/2017             AAPL     12/15/2017        170.0           C
# 4644  07/05/2017             AAPL     12/15/2017        170.0           C
# 6206  07/05/2017             AAPL     12/15/2017        170.0           C
# 7768  07/05/2017             AAPL     12/15/2017        170.0           C
#
#      StartBarTime EndBarTime  OpenBidPrice  OpenAskPrice  HighBidPrice  \
# 1520     09:30:00   09:30:59          1.33          1.75          1.48
# 3082     09:31:00   09:31:59          1.48          1.61          1.50
# 4644     09:32:00   09:32:59          1.50          1.61          1.53
# 6206     09:33:00   09:33:59          1.52          1.57          1.53
# 7768     09:34:00   09:34:59          1.53          1.57          1.53
#
#       HighAskPrice  LowBidPrice  LowAskPrice  CloseBidPrice  CloseBidSize  \
# ...

# %%
df.to_hdf('AAPL_121517_170C.h5', key='table', format='table')

# %%
files = [
        'opra_20170706_bar01_AAPL.csv.gz',
        'opra_20170707_bar01_AAPL.csv.gz',
        'opra_20170710_bar01_AAPL.csv.gz',
        'opra_20170711_bar01_AAPL.csv.gz',
        'opra_20170712_bar01_AAPL.csv.gz',
        'opra_20170713_bar01_AAPL.csv.gz',
        'opra_20170714_bar01_AAPL.csv.gz',
        'opra_20170717_bar01_AAPL.csv.gz',
        'opra_20170718_bar01_AAPL.csv.gz',
        'opra_20170719_bar01_AAPL.csv.gz',
        'opra_20170720_bar01_AAPL.csv.gz',
        'opra_20170721_bar01_AAPL.csv.gz',
        'opra_20170724_bar01_AAPL.csv.gz',
        'opra_20170725_bar01_AAPL.csv.gz',
        'opra_20170726_bar01_AAPL.csv.gz',
        'opra_20170727_bar01_AAPL.csv.gz',
        'opra_20170728_bar01_AAPL.csv.gz',
        'opra_20170731_bar01_AAPL.csv.gz',]

# %%
for file in files:
    df = pd.read_csv(file,header=None)
    df = df.rename(columns=newcols)
    df = df.filter(['TradingDate',
                'UnderlyingTicker',
                'ExpirationDate',
                'StrikePrice',
                'OptionRight',
                'StartBarTime',
                'EndBarTime',
                'OpenBidPrice',
                'OpenAskPrice',
                'HighBidPrice',
                'HighAskPrice',
                'LowBidPrice',
                'LowAskPrice',
                'CloseBidPrice',
                'CloseBidSize',
                'CloseAskPrice',
                'CloseAskSize','MinQuoteSpread',
                'MaxQuoteSpread','NumberOfTrades'], axis=1)
    df = df[(df['ExpirationDate']==expdate)]
    df = df[(df['StrikePrice']==strprice) & (df['OptionRight']==optiontype)]
    df.to_hdf('AAPL_121517_170C.h5', key='table', format='table', append=True)

# %%
test_df = pd.read_hdf('AAPL_121517_170C.h5',key='table')

# %%
test_df.head()
# Out:
#      TradingDate UnderlyingTicker ExpirationDate  StrikePrice OptionRight  \
# 1520  07/05/2017             AAPL     12/15/2017        170.0           C
# 3082  07/05/2017             AAPL     12/15/2017        170.0           C
# 4644  07/05/2017             AAPL     12/15/2017        170.0           C
# 6206  07/05/2017             AAPL     12/15/2017        170.0           C
# 7768  07/05/2017             AAPL     12/15/2017        170.0           C
#
#      StartBarTime EndBarTime  OpenBidPrice  OpenAskPrice  HighBidPrice  \
# 1520     09:30:00   09:30:59          1.33          1.75          1.48
# 3082     09:31:00   09:31:59          1.48          1.61          1.50
# 4644     09:32:00   09:32:59          1.50          1.61          1.53
# 6206     09:33:00   09:33:59          1.52          1.57          1.53
# 7768     09:34:00   09:34:59          1.53          1.57          1.53
#
#       HighAskPrice  LowBidPrice  LowAskPrice  CloseBidPrice  CloseBidSize  \
# ...

# %%
test_df.tail()
# Out:
#        TradingDate UnderlyingTicker ExpirationDate  StrikePrice OptionRight  \
# 594398  07/31/2017             AAPL     12/15/2017        170.0           C
# 595938  07/31/2017             AAPL     12/15/2017        170.0           C
# 597478  07/31/2017             AAPL     12/15/2017        170.0           C
# 599018  07/31/2017             AAPL     12/15/2017        170.0           C
# 600558  07/31/2017             AAPL     12/15/2017        170.0           C
#
#        StartBarTime EndBarTime  OpenBidPrice  OpenAskPrice  HighBidPrice  \
# 594398     15:55:00   15:55:59          1.96          2.04          1.97
# 595938     15:56:00   15:56:59          1.97          2.04          1.97
# 597478     15:57:00   15:57:59          1.95          2.03          1.97
# 599018     15:58:00   15:58:59          1.97          2.03          2.01
# 600558     15:59:00   15:59:59          1.95          2.03          2.00
#
# ...

# %%
test_df.columns
# Out:
# Index(['TradingDate', 'UnderlyingTicker', 'ExpirationDate', 'StrikePrice',
#        'OptionRight', 'StartBarTime', 'EndBarTime', 'OpenBidPrice',
#        'OpenAskPrice', 'HighBidPrice', 'HighAskPrice', 'LowBidPrice',
#        'LowAskPrice', 'CloseBidPrice', 'CloseBidSize', 'CloseAskPrice',
#        'CloseAskSize', 'MinQuoteSpread', 'MaxQuoteSpread', 'NumberOfTrades'],
#       dtype='object')

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7419 entries, 1520 to 600558
# Data columns (total 20 columns):
# TradingDate         7419 non-null object
# UnderlyingTicker    7419 non-null object
# ExpirationDate      7419 non-null object
# StrikePrice         7419 non-null float64
# OptionRight         7419 non-null object
# StartBarTime        7419 non-null object
# EndBarTime          7419 non-null object
# OpenBidPrice        7419 non-null float64
# OpenAskPrice        7419 non-null float64
# HighBidPrice        7419 non-null float64
# HighAskPrice        7419 non-null float64
# LowBidPrice         7419 non-null float64
# LowAskPrice         7419 non-null float64
# CloseBidPrice       7419 non-null float64
# CloseBidSize        7419 non-null int64
# CloseAskPrice       7419 non-null float64
# CloseAskSize        7419 non-null int64
# MinQuoteSpread      7419 non-null float64
# MaxQuoteSpread      7419 non-null float64
# NumberOfTrades      7419 non-null int64
# ...
